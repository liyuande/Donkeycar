# %% [markdown]
# # 最终程序，现在能实现光线上下40%

# %%
# %matplotlib inline
import torch
import torchvision
from torch import nn
from d2l import torch as d2l
import cv2
from PIL import Image
import numpy
import os 
import sys 

def apply(img, aug,file):
    image = aug(img)

    img = cv2.cvtColor(numpy.asarray(image),cv2.COLOR_RGB2BGR)
    cv2.imwrite(r'C:\Users\fangfang\test_picture\testlight'+'\\'+file,img)

    
for file in os.listdir(r'C:\Users\fangfang\test_picture\testlight'):
    if file.endswith(".jpg"):
        img = cv2.imread(r'C:\Users\fangfang\test_picture\testlight'+ '\\'+file)
        img = Image.fromarray(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
        apply(img,torchvision.transforms.ColorJitter(brightness=0.4, contrast=0,saturation=0, hue=0),file)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-66525454d91f> in <module>
#      21         img = cv2.imread(r'C:\Users\fangfang\test_picture\testlight'+ '\\'+file)
#      22         img = Image.fromarray(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
# ---> 23         apply(img,torchvision.transforms.ColorJitter(brightness=0.4, contrast=0,saturation=0, hue=0),file)
#      24
#
# <ipython-input-1-66525454d91f> in apply(img, aug, file)
#      14
#      15     img = cv2.cvtColor(numpy.asarray(image),cv2.COLOR_RGB2BGR)
# ---> 16     cv2.imwrite(r'C:\Users\fangfang\test_picture\testlight'+'\\'+file,img)
#      17
#      18
#
# KeyboardInterrupt:

# %%
# %matplotlib inline
import torch
import torchvision
from torch import nn
from d2l import torch as d2l
import cv2
from PIL import Image
import numpy

# %%
def apply(img, aug):
    image = aug(img)
    d2l.plt.imshow(image)
    img = cv2.cvtColor(numpy.asarray(image),cv2.COLOR_RGB2BGR)
    cv2.imwrite(r'C:\Users\fangfang\test_picture\testlight\291_cam_image_array_.jpg',img)

# %%
img = cv2.imread(r'C:\Users\fangfang\test_picture\testlight\291_cam_image_array_.jpg')

# %%
from PIL import Image
img = Image.fromarray(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
d2l.plt.imshow(img);

# %%
apply(
    img,
    torchvision.transforms.ColorJitter(brightness=0, contrast=0,
                                       saturation=0, hue=0.5))
